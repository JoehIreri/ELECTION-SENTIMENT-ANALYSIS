# %% [markdown]
# <a href="https://colab.research.google.com/github/JoehIreri/Election-Sentiment-Analysis/blob/main/ELECTION_SENTIMENT_ANALYSIS_USING_X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A predictive model that can identify and classify voters based on their twitter behaviours and interactions

# %%
# !pip install TextBlob
# Out:
# Requirement already satisfied: TextBlob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from TextBlob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->TextBlob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->TextBlob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->TextBlob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->TextBlob) (4.66.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS # generate visual representations of text data

# %%
trump=pd.read_csv("/content/Trumpall2.csv")
biden=pd.read_csv("/content/Bidenall2.csv")

# %%
trump.head()
# Out:
#               user                                               text
# 0      manny_rosen   @sanofi please tell us how many shares the Cr...
# 1        osi_abdul   https://t.co/atM98CpqF7  Like, comment, RT #P...
# 2          Patsyrw   Your AG Barr is as useless &amp; corrupt as y...
# 3  seyedebrahimi_m   Mr. Trump! Wake Up!  Most of the comments bel...
# 4    James09254677   After 4 years you think you would have figure...

# %%
biden.head()
# Out:
#            user                                               text
# 0   MarkHodder3    @JoeBiden And we’ll find out who won in 2026...
# 1    K87327961G  @JoeBiden Your Democratic Nazi Party cannot be...
# 2      OldlaceA                        @JoeBiden So did Lying Barr
# 3    penblogger  @JoeBiden It's clear you didnt compose this tw...
# 4  Aquarian0264         @JoeBiden I will vote in person thank you.

# %%
from textblob import TextBlob

trump_txt=TextBlob(trump["text"][500])
print(trump["text"][500])
print("trump:", trump_txt.sentiment)


biden_txt=TextBlob(trump["text"][500])
print(biden["text"][500])
print("biden:", biden_txt.sentiment)
# Out:
#  didn't our very own government fine and reprimand our racist leader and his racist daddy fred for… https://t.co/Pwy354lioG
# trump: Sentiment(polarity=0.5983333333333334, subjectivity=0.75)
# @JoeBiden ... and maybe some kind of healthcare that covers everybody... not that the thought of millions in hospit… https://t.co/v3QKITvlPJ
# biden: Sentiment(polarity=0.5983333333333334, subjectivity=0.75)

# %%
def pol(text):
  return TextBlob(text).sentiment.polarity

trump["Polarity"]=trump["text"].apply(pol)
trump.tail()
# Out:
#                  user                                               text  \
# 2783          4diva63  @realDonaldTrump For the 1/100 time, absentee ...
# 2784         hidge826  @realDonaldTrump If you’re so scared of losing...
# 2785     SpencerRossy  @realDonaldTrump I rarely get involved with fo...
# 2786  ScoobyMcpherson  @realDonaldTrump This is the moment when Trump...
# 2787          bjklinz     @realDonaldTrump I’m sorry, Donald. No. #POTUS
#
#       Polarity
# 2783     0.000
# 2784     0.000
# 2785     0.225
# 2786     0.000
# 2787    -0.500

# %%
trump["Polarity"]=trump["text"].apply(pol)
trump.tail()
# Out:
#                  user                                               text  \
# 2783          4diva63  @realDonaldTrump For the 1/100 time, absentee ...
# 2784         hidge826  @realDonaldTrump If you’re so scared of losing...
# 2785     SpencerRossy  @realDonaldTrump I rarely get involved with fo...
# 2786  ScoobyMcpherson  @realDonaldTrump This is the moment when Trump...
# 2787          bjklinz     @realDonaldTrump I’m sorry, Donald. No. #POTUS
#
#       Polarity
# 2783     0.000
# 2784     0.000
# 2785     0.225
# 2786     0.000
# 2787    -0.500

# %%
trump["sentiment"]=np.where(trump["Polarity"]>0,"Positive","Negative")
trump["sentiment"][trump["Polarity"]==0]="Neutral"
trump.tail()
# Out:
# <ipython-input-33-78c6222bd4ae>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump["sentiment"][trump["Polarity"]==0]="Neutral"
#                  user                                               text  \
# 2783          4diva63  @realDonaldTrump For the 1/100 time, absentee ...
# 2784         hidge826  @realDonaldTrump If you’re so scared of losing...
# 2785     SpencerRossy  @realDonaldTrump I rarely get involved with fo...
# 2786  ScoobyMcpherson  @realDonaldTrump This is the moment when Trump...
# 2787          bjklinz     @realDonaldTrump I’m sorry, Donald. No. #POTUS
#
#       Polarity sentiment
# 2783     0.000   Neutral
# 2784     0.000   Neutral
# 2785     0.225  Positive
# 2786     0.000   Neutral
# 2787    -0.500  Negative

# %%
biden["Polarity"]=biden["text"].apply(pol)
biden.tail()
# Out:
#              user                                               text  Polarity
# 2535    meryn1977  @JoeBiden You'll just try to calm those waters...      0.15
# 2536  BSNelson114  @JoeBiden 96 days 96 dias #VoteJoeBiden2020  #...      0.00
# 2537     KenCapel  @JoeBiden YOU THINK YOU CAN DO THAT??? YOU CAN...      0.00
# 2538   LeslyeHale  @JoeBiden Trump wants our children back at sch...      0.10
# 2539     rerickre  @JoeBiden ... and I know, because it’s much co...      0.20

# %%
print(biden.columns)
# Out:
# Index(['user', 'text'], dtype='object')

# %%
biden["sentiment"]=np.where(biden["Polarity"]>0,"Positive","Negative")
biden["sentiment"][biden["Polarity"]==0]="Neutral"
biden.tail()
# Out:
# <ipython-input-40-b0788d6bf0f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biden["sentiment"][biden["Polarity"]==0]="Neutral"
#              user                                               text  \
# 2535    meryn1977  @JoeBiden You'll just try to calm those waters...
# 2536  BSNelson114  @JoeBiden 96 days 96 dias #VoteJoeBiden2020  #...
# 2537     KenCapel  @JoeBiden YOU THINK YOU CAN DO THAT??? YOU CAN...
# 2538   LeslyeHale  @JoeBiden Trump wants our children back at sch...
# 2539     rerickre  @JoeBiden ... and I know, because it’s much co...
#
#       Polarity sentiment
# 2535      0.15  Positive
# 2536      0.00   Neutral
# 2537      0.00   Neutral
# 2538      0.10  Positive
# 2539      0.20  Positive

# %%
trump_neutral=trump[trump["Polarity"]==0]
print(trump_neutral.shape)
# Out:
# (1464, 4)

# %%
biden_neutral=biden[trump["Polarity"]==0]
print(biden_neutral.shape)
# Out:
# (1318, 4)
# <ipython-input-42-095dc1bfc830>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   biden_neutral=biden[trump["Polarity"]==0]

# %%
print(trump.shape)
print(biden.shape)
# Out:
# (2788, 4)
# (2540, 4)

# %%
trump.drop(trump[trump["Polarity"]==0].index, inplace= True)
print(trump.shape)

biden.drop(biden[biden["Polarity"]==0].index, inplace= True)
print(biden.shape)
# Out:
# (1324, 4)
# (1031, 4)

# %%
print(trump.shape)
print(biden.shape)
# Out:
# (1324, 4)
# (1031, 4)

# %%
count_trump=trump.groupby('sentiment').count()
print(count_trump)

count_biden=biden.groupby('sentiment').count()
print(count_biden)
# Out:
#            user  text  Polarity
# sentiment
# Negative    597   597       597
# Positive    727   727       727
#            user  text  Polarity
# sentiment
# Negative    407   407       407
# Positive    624   624       624

# %%
name=["Trump","Biden"]
list_pos=[count_trump['Polarity'][1],count_biden['Polarity'][1]]
list_neg=[count_trump['Polarity'][0],count_biden['Polarity'][0]]


import plotly.graph_objects as go

colors_pos = ['#40E0D0', '#40E0D0']
colors_neg = ['#707B7C', '#707B7C']

fig=go.Figure(data=[
    go.Bar(name='+ve',x=name, y=list_pos ,marker_color=colors_pos),
    go.Bar(name='-ve', x=name, y=list_neg, marker_color=colors_neg),
])

fig.update_layout(
    title= 'Sentiment Analysis Comparison: Trump vs. Biden',
    barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ec0d16d-0403-453d-b115-19ece5261a01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ec0d16d-0403-453d-b115-19ece5261a01")) {                    Plotly.newPlot(                        "6ec0d16d-0403-453d-b115-19ece5261a01",                        [{"marker":{"color":["#40E0D0","#40E0D0"]},"name":"+ve","x":["Trump","Biden"],"y":[727,624],"type":"bar"},{"marker":{"color":["#707B7C","#707B7C"]},"name":"-ve","x":["Trump","Biden"],"y":[597,407],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":1 ...

# %%
text=" ".join(text for text in trump.text)
text=" ".join(filter(lambda x:x[0]!='@', text.split()))
import re
text=re.sub(r"http\S+", "", text)


print("there have{} words in all text".format(len(text)))
WC=WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)

plt.figure(figsize =(15,10))
plt.imshow(WC, interpolation='bilinear')
# Out:
# there have101858 words in all text

# %%
text=" ".join(text for text in biden.text)
text=" ".join(filter(lambda x:x[0]!='@', text.split()))
import re
text=re.sub(r"http\S+", "", text)


print("there have{} words in all text".format(len(text)))
WC=WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)

plt.figure(figsize =(15,10))
plt.imshow(WC, interpolation='bilinear')
# Out:
# there have84818 words in all text
